# %% [markdown]
# ## Training Models

# %%
import os

# Show NVIDIA GPU status
# !nvidia-smi

# Set the GPU device for training (e.g., GPU 0)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Tue Jun 24 23:19:51 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.52                 Driver Version: 576.52         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0  On |                  N/A |
# | 26%   35C    P8              9W /   75W |     922MiB /   4096MiB |      4%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
print(torch.cuda.is_available())  # should return True
# Out:
# False

# %%
# !yolo detect train data=r'D:\Project12_Yolo_Face\data.yaml' model=yolo11s.pt epochs=10 imgsz=640 batch=16 device=cpu name=yolo11s_face
# Out:
# Ultralytics 8.3.159  Python-3.12.0 torch-2.2.2+cpu CPU (Intel Core(TM) i5-8400 2.80GHz)
# ...
