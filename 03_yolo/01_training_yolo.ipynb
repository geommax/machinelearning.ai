# %% [markdown]
# ## Training Models

# %%
import os

# Show NVIDIA GPU status
# !nvidia-smi

# Set the GPU device for training (e.g., GPU 0)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Wed Jun 25 12:56:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.52                 Driver Version: 576.52         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0  On |                  N/A |
# | 26%   35C    P8             10W /   75W |     918MiB /   4096MiB |     19%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
print(torch.cuda.is_available())  # should return True
# Out:
# True

# %%
# !yolo detect train data=r'D:\Project12_Yolo_Face\data.yaml' model=yolo11s.pt epochs=20 imgsz=640 batch=16 device=0 name=yolo11s_face
## Run the YOLO training command
#---------------------------------------------------
# YOLOv11 Training Script
#---------------------------------------------------
import os
from ultralytics import YOLO

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

model = YOLO('yolo11s.pt')  # Load YOLO model (custom or pre-trained weights)

model.train(
    data=r"D:\Project15_Objects_Detection_YOLO (53 classes)\data\data.yaml",
    cfg =r"D:\Project15_Objects_Detection_YOLO (53 classes)\data\cfg.yaml",
    freeze=10,  # Freeze model layers
    name="Object_detect_53_img_using_aug"
)
# Out:
# Ultralytics 8.3.159  Python-3.10.18 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...
